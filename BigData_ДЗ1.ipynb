# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('abalone.csv')

# %%
data.head()
# Out:
#   Sex  Length  Diameter  ...  Viscera weight  Shell weight  Rings
# 0   M   0.455     0.365  ...          0.1010         0.150     15
# 1   M   0.350     0.265  ...          0.0485         0.070      7
# 2   F   0.530     0.420  ...          0.1415         0.210      9
# 3   M   0.440     0.365  ...          0.1140         0.155     10
# 4   I   0.330     0.255  ...          0.0395         0.055      7
#
# [5 rows x 9 columns]

# %%
data.shape
# Out:
# (4177, 9)

# %%
data.Rings.max()
# Out:
# 29

# %%
data.describe()
# Out:
#             Length     Diameter  ...  Shell weight        Rings
# count  4177.000000  4177.000000  ...   4177.000000  4177.000000
# mean      0.523992     0.407881  ...      0.238831     9.933684
# std       0.120093     0.099240  ...      0.139203     3.224169
# min       0.075000     0.055000  ...      0.001500     1.000000
# 25%       0.450000     0.350000  ...      0.130000     8.000000
# 50%       0.545000     0.425000  ...      0.234000     9.000000
# 75%       0.615000     0.480000  ...      0.329000    11.000000
# max       0.815000     0.650000  ...      1.005000    29.000000
#
# [8 rows x 8 columns]

# %%
data.hist(figsize=(20,10), grid=False, layout=(2, 4), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0665f06358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0665eca438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0665e71908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0665e9ae80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0665e48438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0665def9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0665e19f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0665dc6518>]],
#       dtype=object)

# %%
plt.figure(figsize = (20,7))
sns.swarmplot(x = 'Sex', y = 'age', data = data, hue = 'Sex')
sns.violinplot(x = 'Sex', y = 'age', data = data)

# %%
data.groupby('Sex')[['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
       'Viscera weight', 'Shell weight', 'age']].mean().sort_values('age')
# Out:
#        Length  Diameter    Height  ...  Viscera weight  Shell weight        age
# Sex                                ...
# I    0.427746  0.326494  0.107996  ...        0.092010      0.128182   9.390462
# M    0.561391  0.439287  0.151381  ...        0.215545      0.281969  12.205497
# F    0.579093  0.454732  0.158011  ...        0.230689      0.302010  12.629304
#
# [3 rows x 8 columns]

# %%
numerical_features = data.select_dtypes(include=[np.number]).columns
categorical_features = data.select_dtypes(include=[np.object]).columns

# %%
numerical_features
# Out:
# Index(['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings', 'age'],
#       dtype='object')

# %%
categorical_features
# Out:
# Index(['Sex'], dtype='object')

# %%
sns.pairplot(data[numerical_features])

# %%
plt.figure(figsize=(20,7))
sns.heatmap(data[numerical_features].corr(), annot=True)
