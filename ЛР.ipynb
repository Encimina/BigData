# %%
import pandas as pd
data = pd.read_csv('wine.csv')

# %%
data.head(n=3)
# Out:
#    Cultivar  Alcohol  Malic acid  ...   Hue  OD280/OD315 of diluted wines  Proline
# 0         1    14.23        1.71  ...  1.04                          3.92     1065
# 1         1    13.20        1.78  ...  1.05                          3.40     1050
# 2         1    13.16        2.36  ...  1.03                          3.17     1185
#
# [3 rows x 14 columns]

# %%
data.count()
# Out:
# Cultivar                        178
# Alcohol                         178
# Malic acid                      178
# Ash                             178
# Alcalinity of ash               178
# Magnesium                       178
# Total phenols                   178
# Flavanoids                      178
# Nonflavanoid phenols            178
# Proanthocyanins                 178
# Color intensity                 178
# Hue                             178
# OD280/OD315 of diluted wines    178
# Proline                         178
# dtype: int64

# %%
data.rename(columns=lambda x: x.strip())
# Out:
#      Cultivar  Alcohol  Malic acid  ...   Hue  OD280/OD315 of diluted wines  Proline
# 0           1    14.23        1.71  ...  1.04                          3.92     1065
# 1           1    13.20        1.78  ...  1.05                          3.40     1050
# 2           1    13.16        2.36  ...  1.03                          3.17     1185
# 3           1    14.37        1.95  ...  0.86                          3.45     1480
# 4           1    13.24        2.59  ...  1.04                          2.93      735
# 5           1    14.20        1.76  ...  1.05                          2.85     1450
# 6           1    14.39        1.87  ...  1.02                          3.58     1290
# 7           1    14.06        2.15  ...  1.06                          3.58     1295
# 8           1    14.83        1.64  ...  1.08                          2.85     1045
# 9           1    13.86        1.35  ...  1.01                          3.55     1045
# 10          1    14.10        2.16  ...  1.25                          3.17     1510
# 11          1    14.12        1.48  ...  1.17                          2.82     1280
# 12          1    13.75        1.73  ...  1.15                          2.90     1320
# 13          1    14.75        1.73  ...  1.25                          2.73     1150
# 14          1    14.38        1.87  ...  1.20                          3.00     1547
# 15          1    13.63        1.81  ...  1.28                          2.88     1310
# 16          1    14.30        1.92  ...  1.07                          2.65     1280
# 17          1    13.83        1.57  ...  1.13                          2.57     1130
# 18          1    14.19        1.59  ...  1.23                          2.82     1680
# 19          1    13.64        3.10  ...  0.96                          3.36      845
# 20          1    14.06        1.63  ...  1.09                          3.71      780
# 21          1    12.93        3.80  ...  1.03                          3.52      770
# 22          1    13.71        1.86  ...  1.11                          4.00     1035
# 23          1    12.85        1.60  ...  1.09                          3.63     1015
# 24          1    13.50        1.81  ...  1.12                          3.82      845
# 25          1    13.05        2.05  ...  1.13                          3.20      830
# 26          1    13.39        1.77  ...  0.92                          3.22     1195
# 27          1    13.30        1.72  ...  1.02                          2.77     1285
# 28          1    13.87        1.90  ...  1.25                          3.40      915
# 29          1    14.02        1.68  ...  1.04                          3.59     1035
# ..        ...      ...         ...  ...   ...                           ...      ...
# 148         3    13.32        3.24  ...  0.55                          1.62      650
# 149         3    13.08        3.90  ...  0.57                          1.33      550
# 150         3    13.50        3.12  ...  0.59                          1.30      500
# 151         3    12.79        2.67  ...  0.48                          1.47      480
# 152         3    13.11        1.90  ...  0.61                          1.33      425
# 153         3    13.23        3.30  ...  0.56                          1.51      675
# 154         3    12.58        1.29  ...  0.58                          1.55      640
# 155         3    13.17        5.19  ...  0.60                          1.48      725
# 156         3    13.84        4.12  ...  0.57                          1.64      480
# 157         3    12.45        3.03  ...  0.67                          1.73      880
# 158         3    14.34        1.68  ...  0.57                          1.96      660
# 159         3    13.48        1.67  ...  0.57                          1.78      620
# 160         3    12.36        3.83  ...  0.56                          1.58      520
# 161         3    13.69        3.26  ...  0.96                          1.82      680
# 162         3    12.85        3.27  ...  0.87                          2.11      570
# 163         3    12.96        3.45  ...  0.68                          1.75      675
# 164         3    13.78        2.76  ...  0.70                          1.68      615
# 165         3    13.73        4.36  ...  0.78                          1.75      520
# 166         3    13.45        3.70  ...  0.85                          1.56      695
# 167         3    12.82        3.37  ...  0.72                          1.75      685
# 168         3    13.58        2.58  ...  0.74                          1.80      750
# 169         3    13.40        4.60  ...  0.67                          1.92      630
# 170         3    12.20        3.03  ...  0.66                          1.83      510
# 171         3    12.77        2.39  ...  0.57                          1.63      470
# 172         3    14.16        2.51  ...  0.62                          1.71      660
# 173         3    13.71        5.65  ...  0.64                          1.74      740
# 174         3    13.40        3.91  ...  0.70                          1.56      750
# 175         3    13.27        4.28  ...  0.59                          1.56      835
# 176         3    13.17        2.59  ...  0.60                          1.62      840
# 177         3    14.13        4.10  ...  0.61                          1.60      560
#
# [178 rows x 14 columns]

# %%
mat = data.agg(['min', 'max', 'mean'])
mat
# Out:
#       Cultivar    Alcohol  ...  OD280/OD315 of diluted wines      Proline
# min   1.000000  11.030000  ...                      1.270000   278.000000
# max   3.000000  14.830000  ...                      4.000000  1680.000000
# mean  1.938202  13.000618  ...                      2.611685   746.893258
#
# [3 rows x 14 columns]

# %%
corr = data.corr()
corr
# Out:
#                               Cultivar  ...   Proline
# Cultivar                      1.000000  ... -0.633717
# Alcohol                      -0.328222  ...  0.643720
# Malic acid                    0.437776  ... -0.192011
# Ash                          -0.049643  ...  0.223626
# Alcalinity of ash             0.517859  ... -0.440597
# Magnesium                    -0.209179  ...  0.393351
# Total phenols                -0.719163  ...  0.498115
# Flavanoids                   -0.847498  ...  0.494193
# Nonflavanoid phenols          0.489109  ... -0.311385
# Proanthocyanins              -0.499130  ...  0.330417
# Color intensity               0.265668  ...  0.316100
# Hue                          -0.617369  ...  0.236183
# OD280/OD315 of diluted wines -0.788230  ...  0.312761
# Proline                      -0.633717  ...  1.000000
#
# [14 rows x 14 columns]

# %%
#на всякий случай визуализируем корреляцию
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from pylab import rcParams
rcParams['figure.figsize'] = 12,9


plt.figure(figsize=(7,4)) 
sns.heatmap(corr,annot=True,cmap='cubehelix_r')
plt.show()

# %%
data.hist(figsize=(20,10), grid=False, bins = 50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff717966438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff71780ea20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff7177c4f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff717772550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff717719ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff71774c080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff7176f15f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff717699ba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff717699be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff7177d9f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff7181f4f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff717a99630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff717affb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff717d3a438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff717b73208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff7176be780>]],
#       dtype=object)

# %%
x = data[['Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']]
y = data['Cultivar']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 101)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import *

# %%
rfc_model = RandomForestClassifier(n_estimators=20, max_depth=3)
rfc_model.fit(x_train,y_train)
rfc_predict = rfc_model.predict(x_test)
print ("accuracy: ", accuracy_score(y_test, rfc_predict))
print (classification_report(y_test, rfc_predict))
# Out:
# accuracy:  0.9629629629629629
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        19
#            2       0.95      0.95      0.95        22
#            3       0.92      0.92      0.92        13
#
#     accuracy                           0.96        54
#    macro avg       0.96      0.96      0.96        54
# weighted avg       0.96      0.96      0.96        54
